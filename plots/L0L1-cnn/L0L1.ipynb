# %%
import numpy as np
import re
import matplotlib.pyplot as plt
from scipy.optimize import minimize

def fit_positive_linear(x, y):
    x = np.asarray(x)
    y = np.asarray(y)
    penalty_weight = 10
    
    # Loss function (mean squared error)
    def loss(params):
        a, b = params
        violation = np.maximum(0, y - (a * x + b))  # Capture violations
        penalty = penalty_weight * np.sum(violation ** 2)  # Stronger penalty for violations
        return np.sum((a * x + b - y) ** 2) + penalty
    
    # Initial guess (can be set to 1,1)
    initial_guess = [1.0, 1.0]
    
    # Constraints a > 0, b > 0
    bounds = [(1e-6, None), (1e-6, None)]  # Small threshold to avoid zero
    
    # Run optimization
    result = minimize(loss, initial_guess, bounds=bounds)
    
    return result.x  # Returns [a, b]

# %%
# Sample log file path
log_file_path = "output.txt"  # Change this to your actual log file path

# Lists to store extracted values
L_estimated_values = []
norm_grad_values = []

# Regular expression pattern to match L_estimated and norm_grad lines
pattern = re.compile(r"step:\d+/\d+ \(24\) L_estimated: ([\d\.]+) norm_grad: ([\d\.]+)")

# Read the log file and extract values
with open(log_file_path, "r") as file:
    for line in file:
        match = pattern.search(line)
        if match:
            L_estimated_values.append(float(match.group(1)))  # Extract and convert to float
            norm_grad_values.append(float(match.group(2)))    # Extract and convert to float

# Use extracted values from log file
a, b = fit_positive_linear(norm_grad_values, L_estimated_values)
print(f"Optimal parameters: L_1 = {a:.4f}, L_0 = {b:.4f}")

# Compute vectors
y_actual = np.array(L_estimated_values)
y_predicted = a * np.array(norm_grad_values) + b
x = np.arange(50, 4951, 50)

# Plot results

plt.figure(figsize=(8, 6))
plt.plot(x, y_actual, 'o-', markersize=5, label=r'$L^{\mathrm{estimated}} = \frac{||\nabla f_{\xi^{k+1}}(x^{k+1}) - \nabla f_{\xi^{k}}(x^k)||_*}{||x^{k+1} - x^{k}||}$', color='green')
plt.plot(x, y_predicted, 'o-', markersize=5, 
         label = r'$L^0 + L^1 ||\nabla f_{\xi^{k+1}}(x^{k+1})||_*$' + f', $L^0 = {b:.2f}$, $L^1 = {a:.2f}$', color='blue')
plt.xlabel('iteration $k$', fontsize=16)
plt.legend(fontsize=14)
plt.grid()
plt.title('Name: module._orig_mod.transformer.h.4.attn.c_q.weight\nSize: [768, 768]', fontsize=16)
plt.savefig('plot1.pdf', format='pdf')
plt.show()
# Out:
# Optimal parameters: L_1 = 68.8685, L_0 = 0.0104

# %%
# Sample log file path
log_file_path = "output.txt"  # Change this to your actual log file path

# Lists to store extracted values
L_estimated_values = []
norm_grad_values = []

# Regular expression pattern to match L_estimated and norm_grad lines
pattern = re.compile(r"step:\d+/\d+ \(25\) L_estimated: ([\d\.]+) norm_grad: ([\d\.]+)")

# Read the log file and extract values
with open(log_file_path, "r") as file:
    for line in file:
        match = pattern.search(line)
        if match:
            L_estimated_values.append(float(match.group(1)))  # Extract and convert to float
            norm_grad_values.append(float(match.group(2)))    # Extract and convert to float

# Use extracted values from log file
a, b = fit_positive_linear(norm_grad_values, L_estimated_values)
print(f"Optimal parameters: L_1 = {a:.4f}, L_0 = {b:.4f}")

# Compute vectors
y_actual = np.array(L_estimated_values)
y_predicted = a * np.array(norm_grad_values) + b
x = np.arange(50, 4951, 50)

# Plot results

plt.figure(figsize=(8, 6))
plt.plot(x, y_actual, 'o-', markersize=5, label=r'$L^{\mathrm{estimated}} = \frac{||\nabla f_{\xi^{k+1}}(x^{k+1}) - \nabla f_{\xi^{k}}(x^k)||_*}{||x^{k+1} - x^{k}||}$', color='green')
plt.plot(x, y_predicted, 'o-', markersize=5, 
         label = r'$L^0 + L^1 ||\nabla f_{\xi^{k+1}}(x^{k+1})||_*$' + f', $L^0 = {b:.2f}$, $L^1 = {a:.2f}$', color='blue')
plt.xlabel('iteration $k$', fontsize=16)
plt.legend(fontsize=14)
plt.grid()
plt.title('Name: module._orig_mod.transformer.h.4.attn.c_k.weight\nSize: [768, 768]', fontsize=16)
plt.savefig('plot2.pdf', format='pdf')
plt.show()
# Out:
# Optimal parameters: L_1 = 71.6048, L_0 = 0.0000

# %%
# Sample log file path
log_file_path = "output.txt"  # Change this to your actual log file path

# Lists to store extracted values
L_estimated_values = []
norm_grad_values = []

# Regular expression pattern to match L_estimated and norm_grad lines
pattern = re.compile(r"step:\d+/\d+ \(26\) L_estimated: ([\d\.]+) norm_grad: ([\d\.]+)")

# Read the log file and extract values
with open(log_file_path, "r") as file:
    for line in file:
        match = pattern.search(line)
        if match:
            L_estimated_values.append(float(match.group(1)))  # Extract and convert to float
            norm_grad_values.append(float(match.group(2)))    # Extract and convert to float

# Use extracted values from log file
a, b = fit_positive_linear(norm_grad_values, L_estimated_values)
print(f"Optimal parameters: L_1 = {a:.4f}, L_0 = {b:.4f}")

# Compute vectors
y_actual = np.array(L_estimated_values)
y_predicted = a * np.array(norm_grad_values) + b
x = np.arange(50, 4951, 50)

# Plot results

plt.figure(figsize=(8, 6))
plt.plot(x, y_actual, 'o-', markersize=5, label=r'$L^{\mathrm{estimated}} = \frac{||\nabla f_{\xi^{k+1}}(x^{k+1}) - \nabla f_{\xi^{k}}(x^k)||_*}{||x^{k+1} - x^{k}||}$', color='green')
plt.plot(x, y_predicted, 'o-', markersize=5, 
         label = r'$L^0 + L^1 ||\nabla f_{\xi^{k+1}}(x^{k+1})||_*$' + f', $L^0 = {b:.2f}$, $L^1 = {a:.2f}$', color='blue')
plt.xlabel('iteration $k$', fontsize=16)
plt.legend(fontsize=14)
plt.grid()
plt.title('Name: module._orig_mod.transformer.h.4.attn.c_v.weight\nSize: [768, 768]', fontsize=16)
plt.savefig('plot3.pdf', format='pdf')
plt.show()
# Out:
# Optimal parameters: L_1 = 72.3468, L_0 = 0.0152

# %%
# Sample log file path
log_file_path = "output.txt"  # Change this to your actual log file path

# Lists to store extracted values
L_estimated_values = []
norm_grad_values = []

# Regular expression pattern to match L_estimated and norm_grad lines
pattern = re.compile(r"step:\d+/\d+ \(27\) L_estimated: ([\d\.]+) norm_grad: ([\d\.]+)")

# Read the log file and extract values
with open(log_file_path, "r") as file:
    for line in file:
        match = pattern.search(line)
        if match:
            L_estimated_values.append(float(match.group(1)))  # Extract and convert to float
            norm_grad_values.append(float(match.group(2)))    # Extract and convert to float

# Use extracted values from log file
a, b = fit_positive_linear(norm_grad_values, L_estimated_values)
print(f"Optimal parameters: L_1 = {a:.4f}, L_0 = {b:.4f}")

# Compute vectors
y_actual = np.array(L_estimated_values)
y_predicted = a * np.array(norm_grad_values) + b
x = np.arange(50, 4951, 50)

# Plot results

plt.figure(figsize=(8, 6))
plt.plot(x, y_actual, 'o-', markersize=5, label=r'$L^{\mathrm{estimated}} = \frac{||\nabla f_{\xi^{k+1}}(x^{k+1}) - \nabla f_{\xi^{k}}(x^k)||_*}{||x^{k+1} - x^{k}||}$', color='green')
plt.plot(x, y_predicted, 'o-', markersize=5, 
         label = r'$L^0 + L^1 ||\nabla f_{\xi^{k+1}}(x^{k+1})||_*$' + f', $L^0 = {b:.2f}$, $L^1 = {a:.2f}$', color='blue')
plt.xlabel('iteration $k$', fontsize=16)
plt.legend(fontsize=14)
plt.grid()
plt.title('Name: module._orig_mod.transformer.h.4.attn.c_proj.weight\nSize: [768, 768]', fontsize=16)
plt.savefig('plot4.pdf', format='pdf')
plt.show()
# Out:
# Optimal parameters: L_1 = 69.5601, L_0 = 0.0000

# %%
# Sample log file path
log_file_path = "output.txt"  # Change this to your actual log file path

# Lists to store extracted values
L_estimated_values = []
norm_grad_values = []

# Regular expression pattern to match L_estimated and norm_grad lines
pattern = re.compile(r"step:\d+/\d+ \(28\) L_estimated: ([\d\.]+) norm_grad: ([\d\.]+)")

# Read the log file and extract values
with open(log_file_path, "r") as file:
    for line in file:
        match = pattern.search(line)
        if match:
            L_estimated_values.append(float(match.group(1)))  # Extract and convert to float
            norm_grad_values.append(float(match.group(2)))    # Extract and convert to float

# Use extracted values from log file
a, b = fit_positive_linear(norm_grad_values, L_estimated_values)
print(f"Optimal parameters: L_1 = {a:.4f}, L_0 = {b:.4f}")

# Compute vectors
y_actual = np.array(L_estimated_values)
y_predicted = a * np.array(norm_grad_values) + b
x = np.arange(50, 4951, 50)

# Plot results

plt.figure(figsize=(8, 6))
plt.plot(x, y_actual, 'o-', markersize=5, label=r'$L^{\mathrm{estimated}} = \frac{||\nabla f_{\xi^{k+1}}(x^{k+1}) - \nabla f_{\xi^{k}}(x^k)||_*}{||x^{k+1} - x^{k}||}$', color='green')
plt.plot(x, y_predicted, 'o-', markersize=5, 
         label = r'$L^0 + L^1 ||\nabla f_{\xi^{k+1}}(x^{k+1})||_*$' + f', $L^0 = {b:.2f}$, $L^1 = {a:.2f}$', color='blue')
plt.xlabel('iteration $k$', fontsize=16)
plt.legend(fontsize=14)
plt.grid()
plt.title('Name: module._orig_mod.transformer.h.4.mlp.c_fc.weight\nSize: [3072, 768]', fontsize=16)
plt.savefig('plot5.pdf', format='pdf')
plt.show()
# Out:
# Optimal parameters: L_1 = 70.6599, L_0 = 0.0000

# %%
# Sample log file path
log_file_path = "output.txt"  # Change this to your actual log file path

# Lists to store extracted values
L_estimated_values = []
norm_grad_values = []

# Regular expression pattern to match L_estimated and norm_grad lines
pattern = re.compile(r"step:\d+/\d+ \(29\) L_estimated: ([\d\.]+) norm_grad: ([\d\.]+)")

# Read the log file and extract values
with open(log_file_path, "r") as file:
    for line in file:
        match = pattern.search(line)
        if match:
            L_estimated_values.append(float(match.group(1)))  # Extract and convert to float
            norm_grad_values.append(float(match.group(2)))    # Extract and convert to float

# Use extracted values from log file
a, b = fit_positive_linear(norm_grad_values, L_estimated_values)
print(f"Optimal parameters: L_1 = {a:.4f}, L_0 = {b:.4f}")

# Compute vectors
y_actual = np.array(L_estimated_values)
y_predicted = a * np.array(norm_grad_values) + b
x = np.arange(50, 4951, 50)

# Plot results

plt.figure(figsize=(8, 6))
plt.plot(x, y_actual, 'o-', markersize=5, label=r'$L^{\mathrm{estimated}} = \frac{||\nabla f_{\xi^{k+1}}(x^{k+1}) - \nabla f_{\xi^{k}}(x^k)||_*}{||x^{k+1} - x^{k}||}$', color='green')
plt.plot(x, y_predicted, 'o-', markersize=5, 
         label = r'$L^0 + L^1 ||\nabla f_{\xi^{k+1}}(x^{k+1})||_*$' + f', $L^0 = {b:.2f}$, $L^1 = {a:.2f}$', color='blue')
plt.xlabel('iteration $k$', fontsize=16)
plt.legend(fontsize=14)
plt.grid()
plt.title('Name: module._orig_mod.transformer.h.4.mlp.c_proj.weight\nSize: [768, 3072]', fontsize=16)
plt.savefig('plot6.pdf', format='pdf')
plt.show()
# Out:
# Optimal parameters: L_1 = 72.2290, L_0 = 0.0000

# %%
# Sample log file path
log_file_path = "output.txt"  # Change this to your actual log file path

# Lists to store extracted values
L_estimated_values = []
norm_grad_values = []

# Regular expression pattern to match L_estimated and norm_grad lines
pattern = re.compile(r"step:\d+/\d+ \(72\) L_estimated: ([\d\.]+) norm_grad: ([\d\.]+)")

# Read the log file and extract values
with open(log_file_path, "r") as file:
    for line in file:
        match = pattern.search(line)
        if match:
            L_estimated_values.append(float(match.group(1)))  # Extract and convert to float
            norm_grad_values.append(float(match.group(2)))    # Extract and convert to float

# Use extracted values from log file
a, b = fit_positive_linear(norm_grad_values, L_estimated_values)
print(f"Optimal parameters: L_1 = {a:.4f}, L_0 = {b:.4f}")

# Compute vectors
y_actual = np.array(L_estimated_values)
y_predicted = a * np.array(norm_grad_values) + b
x = np.arange(50, 4951, 50)

# Plot results

plt.figure(figsize=(8, 6))
plt.plot(x, y_actual, 'o-', markersize=3, label=r'$L^{\mathrm{estimated}} = \frac{||\nabla f_{\xi^{k+1}}(x^{k+1}) - \nabla f_{\xi^{k}}(x^k)||_*}{||x^{k+1} - x^{k}||}$', color='green')
plt.plot(x, y_predicted, 'o-', markersize=3, 
         label = r'$L^0 + L^1 ||\nabla f_{\xi^{k+1}}(x^{k+1})||_*$' + f', $L^0 = {b:.2f}$, $L^1 = {a:.2f}$', color='blue')
plt.xlabel('iteration $k$', fontsize=16)
plt.legend(fontsize=14)
plt.grid()
#plt.ylim(0.047, 0.1)
plt.yscale('log')
plt.title('Name: module._orig_mod.transformer.wte.weight\nSize: [50304, 768]', fontsize=16)
plt.savefig('plot7_0.pdf', format='pdf')
plt.show()
# Out:
# Optimal parameters: L_1 = 1.3370, L_0 = 0.0000
