# %%
import numpy as np
import re
import matplotlib.pyplot as plt
from scipy.optimize import minimize

def fit_positive_linear(x, y):
    x = np.asarray(x)
    y = np.asarray(y)
    penalty_weight = 5
    
    # Loss function (mean squared error)
    def loss(params):
        a, b = params
        violation = np.maximum(0, y - (a * x + b))  # Capture violations
        penalty = penalty_weight * np.sum(violation ** 2)  # Stronger penalty for violations
        return np.sum((a * x + b - y) ** 2) + penalty
    
    # Initial guess 
    initial_guess = [1.0, 1.0]
    
    # Constraints a > 0, b > 0
    bounds = [(1e-6, None), (1e-6, None)]  # Small threshold to avoid zero
    
    # Run optimization
    result = minimize(loss, initial_guess, bounds=bounds)
    
    return result.x  # Returns [a, b]

# %%
# Sample log file path
log_file_path = "output.txt"  # Change this to your actual log file path

# Lists to store extracted values
L_estimated_values = []
norm_grad_values = []

# Regular expression pattern to match L_estimated and norm_grad lines
pattern = re.compile(r"step:\d+/\d+ \(48\) L_estimated: ([\d\.]+) norm_grad: ([\d\.]+)")

# Read the log file and extract values
with open(log_file_path, "r") as file:
    for line in file:
        match = pattern.search(line)
        if match:
            L_estimated_values.append(float(match.group(1)))  # Extract and convert to float
            norm_grad_values.append(float(match.group(2)))    # Extract and convert to float

# Use extracted values from log file
a, b = fit_positive_linear(norm_grad_values, L_estimated_values)
print(f"Optimal parameters: L_1 = {a:.4f}, L_0 = {b:.4f}")

# Compute vectors
y_actual = np.array(L_estimated_values)
y_predicted = a * np.array(norm_grad_values) + b
x = np.arange(50, 4951, 50)

# Plot results

plt.figure(figsize=(8, 6))
plt.plot(x, y_actual, 'o-', markersize=5, label=r'$\hat{L}_i$', color='green')
plt.plot(x, y_predicted, 'o-', markersize=5, 
         label = r'$\hat{L}^{approx}_i$' + f': $L_i^0 = {b:.2f}$, $L_i^1 = {a:.2f}$', color='blue')
plt.xlabel('iteration $k$', fontsize=16)
plt.legend(fontsize=14)
plt.grid()
plt.title('Name: module._orig_mod.transformer.h.8.attn.c_q.weight\nSize: [768, 768]', fontsize=16)
plt.savefig('plot1_1.pdf', format='pdf')
plt.show()
# Out:
# Optimal parameters: L_1 = 67.8871, L_0 = 0.0000

# %%
# Sample log file path
log_file_path = "output.txt"  # Change this to your actual log file path

# Lists to store extracted values
L_estimated_values = []
norm_grad_values = []

# Regular expression pattern to match L_estimated and norm_grad lines
pattern = re.compile(r"step:\d+/\d+ \(49\) L_estimated: ([\d\.]+) norm_grad: ([\d\.]+)")

# Read the log file and extract values
with open(log_file_path, "r") as file:
    for line in file:
        match = pattern.search(line)
        if match:
            L_estimated_values.append(float(match.group(1)))  # Extract and convert to float
            norm_grad_values.append(float(match.group(2)))    # Extract and convert to float

# Use extracted values from log file
a, b = fit_positive_linear(norm_grad_values, L_estimated_values)
print(f"Optimal parameters: L_1 = {a:.4f}, L_0 = {b:.4f}")

# Compute vectors
y_actual = np.array(L_estimated_values)
y_predicted = a * np.array(norm_grad_values) + b
x = np.arange(50, 4951, 50)

# Plot results

plt.figure(figsize=(8, 6))
plt.plot(x, y_actual, 'o-', markersize=5, label=r'$\hat{L}_i$', color='green')
plt.plot(x, y_predicted, 'o-', markersize=5, 
         label = r'$\hat{L}^{approx}_i$' + f': $L_i^0 = {b:.2f}$, $L_i^1 = {a:.2f}$', color='blue')
plt.xlabel('iteration $k$', fontsize=16)
plt.legend(fontsize=14)
plt.grid()
plt.title('Name: module._orig_mod.transformer.h.8.attn.c_k.weight\nSize: [768, 768]', fontsize=16)
plt.savefig('plot2_1.pdf', format='pdf')
plt.show()
# Out:
# Optimal parameters: L_1 = 70.8008, L_0 = 0.0000

# %%
# Sample log file path
log_file_path = "output.txt"  # Change this to your actual log file path

# Lists to store extracted values
L_estimated_values = []
norm_grad_values = []

# Regular expression pattern to match L_estimated and norm_grad lines
pattern = re.compile(r"step:\d+/\d+ \(50\) L_estimated: ([\d\.]+) norm_grad: ([\d\.]+)")

# Read the log file and extract values
with open(log_file_path, "r") as file:
    for line in file:
        match = pattern.search(line)
        if match:
            L_estimated_values.append(float(match.group(1)))  # Extract and convert to float
            norm_grad_values.append(float(match.group(2)))    # Extract and convert to float

# Use extracted values from log file
a, b = fit_positive_linear(norm_grad_values, L_estimated_values)
print(f"Optimal parameters: L_1 = {a:.4f}, L_0 = {b:.4f}")

# Compute vectors
y_actual = np.array(L_estimated_values)
y_predicted = a * np.array(norm_grad_values) + b
x = np.arange(50, 4951, 50)

# Plot results

plt.figure(figsize=(8, 6))
plt.plot(x, y_actual, 'o-', markersize=5, label=r'$\hat{L}_i$', color='green')
plt.plot(x, y_predicted, 'o-', markersize=5, 
         label = r'$\hat{L}^{approx}_i$' + f': $L_i^0 = {b:.2f}$, $L_i^1 = {a:.2f}$', color='blue')
plt.xlabel('iteration $k$', fontsize=16)
plt.legend(fontsize=14)
plt.grid()
plt.title('Name: module._orig_mod.transformer.h.8.attn.c_v.weight\nSize: [768, 768]', fontsize=16)
plt.savefig('plot3_1.pdf', format='pdf')
plt.show()
# Out:
# Optimal parameters: L_1 = 71.4575, L_0 = 0.0000

# %%
# Sample log file path
log_file_path = "output.txt"  # Change this to your actual log file path

# Lists to store extracted values
L_estimated_values = []
norm_grad_values = []

# Regular expression pattern to match L_estimated and norm_grad lines
pattern = re.compile(r"step:\d+/\d+ \(51\) L_estimated: ([\d\.]+) norm_grad: ([\d\.]+)")

# Read the log file and extract values
with open(log_file_path, "r") as file:
    for line in file:
        match = pattern.search(line)
        if match:
            L_estimated_values.append(float(match.group(1)))  # Extract and convert to float
            norm_grad_values.append(float(match.group(2)))    # Extract and convert to float

# Use extracted values from log file
a, b = fit_positive_linear(norm_grad_values, L_estimated_values)
print(f"Optimal parameters: L_1 = {a:.4f}, L_0 = {b:.4f}")

# Compute vectors
y_actual = np.array(L_estimated_values)
y_predicted = a * np.array(norm_grad_values) + b
x = np.arange(50, 4951, 50)

# Plot results

plt.figure(figsize=(8, 6))
plt.plot(x, y_actual, 'o-', markersize=5, label=r'$\hat{L}_i$', color='green')
plt.plot(x, y_predicted, 'o-', markersize=5, 
         label = r'$\hat{L}^{approx}_i$' + f': $L_i^0 = {b:.2f}$, $L_i^1 = {a:.2f}$', color='blue')
plt.xlabel('iteration $k$', fontsize=16)
plt.legend(fontsize=14)
plt.grid()
plt.title('Name: module._orig_mod.transformer.h.8.attn.c_proj.weight\nSize: [768, 768]', fontsize=16)
plt.savefig('plot4_1.pdf', format='pdf')
plt.show()
# Out:
# Optimal parameters: L_1 = 68.9648, L_0 = 0.0000

# %%
# Sample log file path
log_file_path = "output.txt"  # Change this to your actual log file path

# Lists to store extracted values
L_estimated_values = []
norm_grad_values = []

# Regular expression pattern to match L_estimated and norm_grad lines
pattern = re.compile(r"step:\d+/\d+ \(52\) L_estimated: ([\d\.]+) norm_grad: ([\d\.]+)")

# Read the log file and extract values
with open(log_file_path, "r") as file:
    for line in file:
        match = pattern.search(line)
        if match:
            L_estimated_values.append(float(match.group(1)))  # Extract and convert to float
            norm_grad_values.append(float(match.group(2)))    # Extract and convert to float

# Use extracted values from log file
a, b = fit_positive_linear(norm_grad_values, L_estimated_values)
print(f"Optimal parameters: L_1 = {a:.4f}, L_0 = {b:.4f}")

# Compute vectors
y_actual = np.array(L_estimated_values)
y_predicted = a * np.array(norm_grad_values) + b
x = np.arange(50, 4951, 50)

# Plot results

plt.figure(figsize=(8, 6))
plt.plot(x, y_actual, 'o-', markersize=5, label=r'$\hat{L}_i$', color='green')
plt.plot(x, y_predicted, 'o-', markersize=5, 
         label = r'$\hat{L}^{approx}_i$' + f': $L_i^0 = {b:.2f}$, $L_i^1 = {a:.2f}$', color='blue')
plt.xlabel('iteration $k$', fontsize=16)
plt.legend(fontsize=14)
plt.grid()
plt.title('Name: module._orig_mod.transformer.h.8.mlp.c_fc.weight\nSize: [3072, 768]', fontsize=16)
plt.savefig('plot5_1.pdf', format='pdf')
plt.show()
# Out:
# Optimal parameters: L_1 = 69.4286, L_0 = 0.0230

# %%
# Sample log file path
log_file_path = "output.txt"  # Change this to your actual log file path

# Lists to store extracted values
L_estimated_values = []
norm_grad_values = []

# Regular expression pattern to match L_estimated and norm_grad lines
pattern = re.compile(r"step:\d+/\d+ \(53\) L_estimated: ([\d\.]+) norm_grad: ([\d\.]+)")

# Read the log file and extract values
with open(log_file_path, "r") as file:
    for line in file:
        match = pattern.search(line)
        if match:
            L_estimated_values.append(float(match.group(1)))  # Extract and convert to float
            norm_grad_values.append(float(match.group(2)))    # Extract and convert to float

# Use extracted values from log file
a, b = fit_positive_linear(norm_grad_values, L_estimated_values)
print(f"Optimal parameters: L_1 = {a:.4f}, L_0 = {b:.4f}")

# Compute vectors
y_actual = np.array(L_estimated_values)
y_predicted = a * np.array(norm_grad_values) + b
x = np.arange(50, 4951, 50)

# Plot results

plt.figure(figsize=(8, 6))
plt.plot(x, y_actual, 'o-', markersize=5, label=r'$\hat{L}_i$', color='green')
plt.plot(x, y_predicted, 'o-', markersize=5, 
         label = r'$\hat{L}^{approx}_i$' + f': $L_i^0 = {b:.2f}$, $L_i^1 = {a:.2f}$', color='blue')
plt.xlabel('iteration $k$', fontsize=16)
plt.legend(fontsize=14)
plt.grid()
plt.title('Name: module._orig_mod.transformer.h.8.mlp.c_proj.weight\nSize: [768, 3072]', fontsize=16)
plt.savefig('plot6_1.pdf', format='pdf')
plt.show()
# Out:
# Optimal parameters: L_1 = 70.1092, L_0 = 0.0000

# %%
# Sample log file path
log_file_path = "output.txt"  # Change this to your actual log file path

# Lists to store extracted values
L_estimated_values = []
norm_grad_values = []

# Regular expression pattern to match L_estimated and norm_grad lines
pattern = re.compile(r"step:\d+/\d+ \(72\) L_estimated: ([\d\.]+) norm_grad: ([\d\.]+)")

# Read the log file and extract values
with open(log_file_path, "r") as file:
    for line in file:
        match = pattern.search(line)
        if match:
            L_estimated_values.append(float(match.group(1)))  # Extract and convert to float
            norm_grad_values.append(float(match.group(2)))    # Extract and convert to float

# Use extracted values from log file
a, b = fit_positive_linear(norm_grad_values, L_estimated_values)
print(f"Optimal parameters: L_1 = {a:.4f}, L_0 = {b:.4f}")

# Compute vectors
y_actual = np.array(L_estimated_values)
y_predicted = a * np.array(norm_grad_values) + b
x = np.arange(50, 4951, 50)

# Plot results

plt.figure(figsize=(8, 6))
plt.plot(x, y_actual, 'o-', markersize=2, label=r'$\hat{L}_i$', color='green')
plt.plot(x, y_predicted, 'o-', markersize=2, 
         label = r'$\hat{L}^{approx}_i$' + f': $L_i^0 = {b:.2f}$, $L_i^1 = {a:.2f}$', color='blue')
plt.xlabel('iteration $k$', fontsize=16)
plt.legend(fontsize=14)
plt.grid()
#plt.ylim(0.047, 0.1)
plt.yscale('log')
plt.title('Name: module._orig_mod.transformer.wte.weight\nSize: [50304, 768]', fontsize=16)
plt.savefig('plot7_0.pdf', format='pdf')
plt.show()
# Out:
# Optimal parameters: L_1 = 1.3370, L_0 = 0.0000
